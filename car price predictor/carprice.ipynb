# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("quikr_car.csv")
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df.head(20)
# Out:
#                                       name   company  year          Price  \
# 0     Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                  Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2               Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3   Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4         Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# 5         Ford EcoSport Titanium 1.5L TDCi      Ford  2015  Ask For Price
# 6                                Ford Figo      Ford  2012       1,75,000
# 7                              Hyundai Eon   Hyundai  2013       1,90,000
# 8         Ford EcoSport Ambiente 1.5L TDCi      Ford  2016       8,30,000
# 9           Maruti Suzuki Alto K10 VXi AMT    Maruti  2015       2,50,000
# 10             Skoda Fabia Classic 1.2 MPI     Skoda  2010       1,82,000
# 11              Maruti Suzuki Stingray VXi    Maruti  2015       3,15,000
# ...

# %%
x=(df['company'].value_counts()>20)
x
# Out:
# company
# Maruti         True
# Hyundai        True
# Mahindra       True
# Tata           True
# Honda          True
# Toyota         True
# Chevrolet      True
# Renault        True
# Ford           True
# Volkswagen    False
# Skoda         False
# Audi          False
# Datsun        False
# Mini          False
# BMW           False
# Nissan        False
# Commercial    False
# Mercedes      False
# Mitsubishi    False
# Force         False
# Fiat          False
# tata          False
# Hindustan     False
# I             False
# MARUTI        False
# urgent        False
# Used          False
# Jaguar        False
# Sale          False
# Well          False
# Any           False
# TATA          False
# sell          False
# scratch       False
# 9             False
# 7             False
# all           False
# Land          False
# 2012          False
# i             False
# Volvo         False
# very          False
# Jeep          False
# Swift         False
# URJENT        False
# ...

# %%
x.sum()
# Out:
# 9

# %%
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df['name'].value_counts()
# Out:
# name
# Honda City                         13
# Honda Amaze                        11
# Maruti Suzuki Dzire                10
# Mahindra Scorpio S10                9
# Maruti Suzuki Alto 800 Lxi          9
#                                    ..
# Mahindra Bolero DI BSII             1
# Audi Q3 2.0 TDI quattro Premium     1
# Skoda Superb 1.8 TFSI AT            1
# BMW 5 Series 520d Sedan             1
# Chevrolet Sail 1.2 LT ABS           1
# Name: count, Length: 525, dtype: int64

# %%
df['year'].value_counts().sort_values(ascending=True).head(30)
# Out:
# year
# D...    1
# go .    1
# r...    1
# o c4    1
# zire    1
# EV2     1
# cent    1
# Sumo    1
# cab     1
# sell    1
# t xe    1
# d Ex    1
# tion    1
# digo    1
# odel    1
# 150k    1
# TOUR    1
# r 15    1
# /-Rs    1
# ara)    1
# SELL    1
# 2 bs    1
# SALE    1
# arry    1
# Eon     1
# ture    1
# emi     1
# able    1
# , Ac    1
# no.     1
# Name: count, dtype: int64

# %%
def f(x):
    if(x.isdigit()):
        return True
    return False

x=df['year'].apply(f)
x.sum()
# Out:
# 842

# %%
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df1=df[x]
df1
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    object
#  3   Price       842 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 46.0+ KB

# %%
df1['year'].value_counts()
# Out:
# year
# 2015    117
# 2014     94
# 2013     94
# 2016     76
# 2012     75
# 2011     60
# 2009     56
# 2017     56
# 2010     44
# 2018     34
# 2006     22
# 2019     22
# 2007     19
# 2008     16
# 2005     13
# 2003     13
# 2004     12
# 2000      7
# 2002      5
# 2001      5
# 1995      2
# Name: count, dtype: int64

# %%
df2=df1
df2
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
df2['year']=df2['year'].astype('int64')
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_5028\445714688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['year']=df2['year'].astype('int64')

# %%
df2
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int64
#  3   Price       842 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 46.0+ KB

# %%
df2['year'].nunique()
# Out:
# 21

# %%
df2['fuel_type'].isnull().sum()
# Out:
# 5

# %%
df3=df2
df3.dropna(subset=['fuel_type'], inplace=True)
df3
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_5028\2605168386.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.dropna(subset=['fuel_type'], inplace=True)
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 837 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        837 non-null    object
#  1   company     837 non-null    object
#  2   year        837 non-null    int64
#  3   Price       837 non-null    object
#  4   kms_driven  837 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 45.8+ KB

# %%
df3['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    440
# Diesel    395
# LPG         2
# Name: count, dtype: int64

# %%
df3['Price'].value_counts()
# Out:
# Price
# Ask For Price    21
# 2,50,000         16
# 3,50,000         12
# 4,00,000         11
# 1,30,000         11
#                  ..
# 7,49,999          1
# 11,30,000         1
# 10,74,999         1
# 3,24,999          1
# 5,00,001          1
# Name: count, Length: 273, dtype: int64

# %%
df4=df3
df4=df4[df4['Price']!='Ask For Price']
df4
# Out:
#                                        name   company  year     Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  5,75,000
# 6                                 Ford Figo      Ford  2012  1,75,000
# ..                                      ...       ...   ...       ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009  1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009  3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018  2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013  3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    object
#  4   kms_driven  816 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 44.6+ KB

# %%
df4
# Out:
#                                        name   company  year     Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  5,75,000
# 6                                 Ford Figo      Ford  2012  1,75,000
# ..                                      ...       ...   ...       ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009  1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009  3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018  2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013  3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# ...

# %%
df4['Price']=df4['Price'].str.replace(',','')
df4
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_5028\2212977429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Price']=df4['Price'].str.replace(',','')
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# ...

# %%
df4['Price']=df4['Price'].astype('int64')
df4
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_5028\2733319457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Price']=df4['Price'].astype('int64')
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.6+ KB

# %%
df4['kms_driven'].value_counts()
# Out:
# kms_driven
# 45,000 kms      30
# 35,000 kms      29
# 55,000 kms      25
# 50,000 kms      23
# 20,000 kms      21
#                 ..
# 1,00,200 kms     1
# 65 kms           1
# 30,874 kms       1
# 1,03,553 kms     1
# 1,32,000 kms     1
# Name: count, Length: 248, dtype: int64

# %%
df4
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# 4      36,000 kms    Diesel
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.6+ KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.6+ KB

# %%
df4
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# 4      36,000 kms    Diesel
# ...

# %%
df5=df4
df5
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# 4      36,000 kms    Diesel
# ...

# %%
df5
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 3      28,000 kms    Petrol
# 4      36,000 kms    Diesel
# ...

# %%
df5['kms_driven']=df5['kms_driven'].str.split().str.get(0).str.replace(',','')
df5
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_5028\1182846250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['kms_driven']=df5['kms_driven'].str.split().str.get(0).str.replace(',','')
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.6+ KB

# %%
df5['kms_driven']=df5['kms_driven'].astype('int64')
df5
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_5028\592531286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['kms_driven']=df5['kms_driven'].astype('int64')
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 44.6+ KB

# %%
df5['company'].nunique()
# Out:
# 25

# %%
df5
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0         45000    Petrol
# 1            40    Diesel
# 3         28000    Petrol
# 4         36000    Diesel
# ...

# %%
df['name'].str.split()
# Out:
# 0        [Hyundai, Santro, Xing, XO, eRLX, Euro, III]
# 1                        [Mahindra, Jeep, CL550, MDI]
# 2                    [Maruti, Suzuki, Alto, 800, Vxi]
# 3      [Hyundai, Grand, i10, Magna, 1.2, Kappa, VTVT]
# 4              [Ford, EcoSport, Titanium, 1.5L, TDCi]
#                             ...
# 887                                              [Ta]
# 888                          [Tata, Zest, XM, Diesel]
# 889                            [Mahindra, Quanto, C8]
# 890                   [Honda, Amaze, 1.2, E, i, VTEC]
# 891                   [Chevrolet, Sail, 1.2, LT, ABS]
# Name: name, Length: 892, dtype: object

# %%
df5['name']=df5['name'].str.split().str.slice(start=0,stop=3).str.join(' ')
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_5028\1726369325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['name']=df5['name'].str.split().str.slice(start=0,stop=3).str.join(' ')

# %%
df5
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 44.6+ KB

# %%
df5['name'].value_counts()
# Out:
# name
# Maruti Suzuki Swift            51
# Maruti Suzuki Alto             42
# Maruti Suzuki Wagon            28
# Maruti Suzuki Ertiga           16
# Hyundai Santro Xing            15
#                                ..
# Mercedes Benz A                 1
# Tata Manza ELAN                 1
# Volkswagen Polo Comfortline     1
# Nissan Sunny                    1
# Tata Zest XM                    1
# Name: count, Length: 254, dtype: int64

# %% [markdown]
# # exploaratory data analysis

# %%
df5
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
df5.describe()
# Out:
#               year         Price     kms_driven
# count   816.000000  8.160000e+02     816.000000
# mean   2012.444853  4.117176e+05   46275.531863
# std       4.002992  4.751844e+05   34297.428044
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.750000e+05   27000.000000
# 50%    2013.000000  2.999990e+05   41000.000000
# 75%    2015.000000  4.912500e+05   56818.500000
# max    2019.000000  8.500003e+06  400000.000000

# %%
df5[(df5['Price']==(df5['Price'].min()))]
# Out:
#                      name company  year  Price  kms_driven fuel_type
# 389  Maruti Suzuki Maruti  Maruti  1995  30000       55000    Petrol
# 851     Maruti Suzuki 800  Maruti  2000  30000       33400    Petrol

# %%
df5
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
df6=df5.copy()
df6=df6[(df6['Price']!=df6['Price'].max())]

# %%
df6
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [815 rows x 6 columns]

# %%
sns.boxplot(df6['Price'])
# Out:
# <Axes: >

# %%
sns.kdeplot(df6['Price'])
# Out:
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Price', ylabel='Density'>

# %%
q1 = df6['Price'].quantile(0.25)
q3 = df6['Price'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
df7=df6[(df6['Price']>=lower_bound) & (df6['Price'] <= upper_bound)]
df7
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [763 rows x 6 columns]

# %%
sns.kdeplot(df7['Price'])
# Out:
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df7['kms_driven'].describe()
# Out:
# count       763.000000
# mean      46890.099607
# std       34119.986215
# min           0.000000
# 25%       28000.000000
# 50%       42000.000000
# 75%       58000.000000
# max      400000.000000
# Name: kms_driven, dtype: float64

# %%
sns.boxplot(df7['kms_driven'])
# Out:
# <Axes: >

# %%
sns.kdeplot(df7['kms_driven'])
# Out:
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='kms_driven', ylabel='Density'>

# %%
df7[df7['kms_driven']==df7['kms_driven'].max()]
# Out:
#                name company  year   Price  kms_driven fuel_type
# 362  Honda City 1.5   Honda  2010  240000      400000    Petrol

# %%
# correlation between price and km driven
df7['Price'].corr(df7['kms_driven'])
# Out:
# -0.14327764249758404

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df7, x='kms_driven', y='Price')
plt.title('Scatter plot of Price vs Kms Driven')
plt.xlabel('Kms Driven')
plt.ylabel('Price')
plt.grid(True)
plt.show()
# Out:
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df7.groupby(df7['company'])['kms_driven'].mean().round(0).sort_values(ascending=False)
# Out:
# company
# Hindustan     87333.0
# Tata          76936.0
# Toyota        62795.0
# Fiat          57800.0
# Nissan        52100.0
# Skoda         51420.0
# Mitsubishi    50000.0
# Honda         49399.0
# BMW           49009.0
# Volkswagen    48791.0
# Chevrolet     48192.0
# Mahindra      47169.0
# Ford          43181.0
# Maruti        42750.0
# Hyundai       38877.0
# Force         37400.0
# Audi          36978.0
# Renault       32547.0
# Mercedes      28000.0
# Datsun        12700.0
# Jeep           3528.0
# Name: kms_driven, dtype: float64

# %%
df7['company'].value_counts()
# Out:
# company
# Maruti        219
# Hyundai       137
# Mahindra       91
# Tata           65
# Honda          60
# Chevrolet      34
# Renault        33
# Toyota         32
# Ford           29
# Volkswagen     18
# Skoda          13
# Datsun          7
# Nissan          5
# Fiat            4
# Force           4
# Audi            3
# Hindustan       3
# BMW             2
# Mercedes        2
# Mitsubishi      1
# Jeep            1
# Name: count, dtype: int64

# %%
df7['name'].value_counts()
# Out:
# name
# Maruti Suzuki Swift      51
# Maruti Suzuki Alto       42
# Maruti Suzuki Wagon      28
# Maruti Suzuki Ertiga     15
# Hyundai Elite i20        15
#                          ..
# Tata Vista Quadrajet      1
# Skoda Rapid Elegance      1
# Mahindra Bolero Power     1
# Hyundai Verna             1
# Tata Zest XM              1
# Name: count, Length: 230, dtype: int64

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='company',y='Price',data=df7)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
df7['Price'].corr(df7['year'])
# Out:
# 0.5029184931041694

# %%
sns.boxplot(data=df7,x='year',y='Price')
# Out:
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='year', ylabel='Price'>

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 763 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        763 non-null    object
#  1   company     763 non-null    object
#  2   year        763 non-null    int64
#  3   Price       763 non-null    int64
#  4   kms_driven  763 non-null    int64
#  5   fuel_type   763 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 57.9+ KB

# %%
sns.boxplot(data=df7,x='fuel_type',y='kms_driven')
# Out:
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='fuel_type', ylabel='kms_driven'>

# %%
df7['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    411
# Diesel    350
# LPG         2
# Name: count, dtype: int64

# %%
ax=sns.relplot(x='company',y='Price',data=df7,hue='fuel_type',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')
# Out:
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df7
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [763 rows x 6 columns]

# %%
X=df7[['name','company','year','kms_driven','fuel_type']]
Y=df7['Price']

# %%
X
# Out:
#                        name   company  year  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014       36000    Diesel
# 6                 Ford Figo      Ford  2012       41000    Diesel
# ..                      ...       ...   ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011       50000    Petrol
# 885          Tata Indica V2      Tata  2009       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009      132000    Petrol
# 888            Tata Zest XM      Tata  2018       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013       40000    Diesel
#
# [763 rows x 5 columns]

# %%
Y
# Out:
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 883    270000
# 885    110000
# 886    300000
# 888    260000
# 889    390000
# Name: Price, Length: 763, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
ohe=OneHotEncoder()

# %%
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A4 1.8', 'Audi Q7', 'BMW 3 Series', 'BMW 5 Series',
#        'Chevrolet Beat', 'Chevrolet Beat Diesel', 'Chevrolet Beat LS',
#        'Chevrolet Beat LT', 'Chevrolet Beat PS', 'Chevrolet Cruze LTZ',
#        'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4', 'Chevrolet S...
#        'Volkswagen Vento Konekt'], dtype=object),
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jeep', 'Mahindra', 'Maruti',
#        'Mercedes', 'Mitsubishi', 'Nissan', 'Renault', 'Skoda', 'Tata',
#        'Toyota', 'Volkswagen'], dtype=object),
# ...

# %%
Y_pred=pipe.predict(X_test)

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.7343228247351368

# %%
Y
# Out:
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 883    270000
# 885    110000
# 886    300000
# 888    260000
# 889    390000
# Name: Price, Length: 763, dtype: int64

# %%
scores=[]
for i in range(1000):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,Y_train)
    Y_pred=pipe.predict(X_test)
    scores.append(r2_score(Y_test,Y_pred))
np.argmax(scores)
# Out:
# 830

# %%
scores[np.argmax(scores)]
# Out:
# 0.8045891430797483

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,Y_train)
Y_pred=pipe.predict(X_test)
r2_score(Y_test,Y_pred)
# Out:
# 0.8045891430797483

# %%
import pickle
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([422213.84796842])

# %%
df7.to_csv('Cleaned_Car_data.csv')
