# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df=pd.read_csv(r"C:\Users\suhanva savyasachi s\Desktop\Bengaluru_House_Data.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.drop(['availability'],axis=1,inplace=True)

# %%
df
# Out:
#                   area_type                  location total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II       1056   2.0
# 1                Plot  Area          Chikka Tirupathi       2600   5.0
# 2            Built-up  Area               Uttarahalli       1440   2.0
# 3      Super built-up  Area        Lingadheeranahalli       1521   3.0
# 4      Super built-up  Area                  Kothanur       1200   2.0
# ...                     ...                       ...        ...   ...
# 13315        Built-up  Area                Whitefield       3453   4.0
# 13316  Super built-up  Area             Richards Town       3600   5.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar       1141   2.0
# 13318  Super built-up  Area           Padmanabhanagar       4689   4.0
# 13319  Super built-up  Area              Doddathoguru        550   1.0
#
#        balcony   price bhk
# 0          1.0   39.07   2
# 1          3.0  120.00   4
# 2          3.0   62.00   3
# ...

# %%
df.dropna(subset=['size'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16600\1608578943.py in ?()
# ----> 1 df.dropna(subset=['size'], inplace=True)
#
# c:\Users\suhanva savyasachi s\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6414             ax = self._get_axis(agg_axis)
#    6415             indices = ax.get_indexer_for(subset)
#    6416             check = indices == -1
#    6417             if check.any():
# -> 6418                 raise KeyError(np.array(subset)[check].tolist())
#    6419             agg_obj = self.take(indices, axis=agg_axis)
#    6420
#    6421         if thresh is not lib.no_default:
#
# KeyError: ['size']

# %%
df.isnull().sum()
# Out:
# area_type       0
# location        1
# size            0
# total_sqft      0
# bath           57
# balcony       593
# price           0
# dtype: int64

# %%
df['bhk']=df['size'].apply(lambda x: x.split(" ")[0])

# %%
df.drop('size',inplace=True,axis=1)

# %%
df
# Out:
#                   area_type                  location total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II       1056   2.0
# 1                Plot  Area          Chikka Tirupathi       2600   5.0
# 2            Built-up  Area               Uttarahalli       1440   2.0
# 3      Super built-up  Area        Lingadheeranahalli       1521   3.0
# 4      Super built-up  Area                  Kothanur       1200   2.0
# ...                     ...                       ...        ...   ...
# 13315        Built-up  Area                Whitefield       3453   4.0
# 13316  Super built-up  Area             Richards Town       3600   5.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar       1141   2.0
# 13318  Super built-up  Area           Padmanabhanagar       4689   4.0
# 13319  Super built-up  Area              Doddathoguru        550   1.0
#
#        balcony   price bhk
# 0          1.0   39.07   2
# 1          3.0  120.00   4
# 2          3.0   62.00   3
# ...

# %%
df['bhk']=df['bhk'].astype(int)

# %%
def f(x):
    try:
        float(x)
    except:
        if('-' in x):
            l=x.split('-')
            return (float(l[0])+float(l[1]))/2
        else:
            return None
    return float(x)
x=df['total_sqft'].apply(f)
df['total_sqft']=x

# %%
df
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0   2.0
# 1                Plot  Area          Chikka Tirupathi      2600.0   5.0
# 2            Built-up  Area               Uttarahalli      1440.0   2.0
# 3      Super built-up  Area        Lingadheeranahalli      1521.0   3.0
# 4      Super built-up  Area                  Kothanur      1200.0   2.0
# ...                     ...                       ...         ...   ...
# 13315        Built-up  Area                Whitefield      3453.0   4.0
# 13316  Super built-up  Area             Richards Town      3600.0   5.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0   2.0
# 13318  Super built-up  Area           Padmanabhanagar      4689.0   4.0
# 13319  Super built-up  Area              Doddathoguru       550.0   1.0
#
#        balcony   price  bhk
# 0          1.0   39.07    2
# 1          3.0  120.00    4
# ...

# %%
df.dropna(subset=['location'],inplace=True)

# %%
df.isnull().sum()
# Out:
# area_type       0
# location        0
# total_sqft     46
# bath           57
# balcony       593
# price           0
# bhk             0
# dtype: int64

# %%
from sklearn.impute import KNNImputer,SimpleImputer
knn = KNNImputer(n_neighbors=3,weights='distance')
xx=df[['total_sqft','bath','balcony']]
yy=knn.fit_transform(xx)
yy = pd.DataFrame(yy, columns=xx.columns, index=xx.index)
yy
# Out:
#        total_sqft  bath   balcony
# 0          1056.0   2.0  1.000000
# 1          2600.0   5.0  3.000000
# 2          1440.0   2.0  3.000000
# 3          1521.0   3.0  1.000000
# 4          1200.0   2.0  1.000000
# ...           ...   ...       ...
# 13315      3453.0   4.0  0.000000
# 13316      3600.0   5.0  1.333333
# 13317      1141.0   2.0  1.000000
# 13318      4689.0   4.0  1.000000
# 13319       550.0   1.0  1.000000
#
# [13303 rows x 3 columns]

# %%
df.update(yy)
df
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0   2.0
# 1                Plot  Area          Chikka Tirupathi      2600.0   5.0
# 2            Built-up  Area               Uttarahalli      1440.0   2.0
# 3      Super built-up  Area        Lingadheeranahalli      1521.0   3.0
# 4      Super built-up  Area                  Kothanur      1200.0   2.0
# ...                     ...                       ...         ...   ...
# 13315        Built-up  Area                Whitefield      3453.0   4.0
# 13316  Super built-up  Area             Richards Town      3600.0   5.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0   2.0
# 13318  Super built-up  Area           Padmanabhanagar      4689.0   4.0
# 13319  Super built-up  Area              Doddathoguru       550.0   1.0
#
#         balcony   price  bhk
# 0      1.000000   39.07    2
# 1      3.000000  120.00    4
# ...

# %%
df.isnull().sum()
# Out:
# area_type     0
# location      0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# bhk           0
# dtype: int64

# %%
df['bath']=df['bath'].astype(int)
df['balcony']=df['balcony'].astype(int)
df=df.drop([3853,1718,1768,3379,3853,4684,4916,9935],axis=0)

# %%
df
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 1                Plot  Area          Chikka Tirupathi      2600.0     5
# 2            Built-up  Area               Uttarahalli      1440.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# ...                     ...                       ...         ...   ...
# 13315        Built-up  Area                Whitefield      3453.0     4
# 13316  Super built-up  Area             Richards Town      3600.0     5
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0     2
# 13318  Super built-up  Area           Padmanabhanagar      4689.0     4
# 13319  Super built-up  Area              Doddathoguru       550.0     1
#
#        balcony   price  bhk
# 0            1   39.07    2
# 1            3  120.00    4
# ...

# %%
df.isnull().sum()
# Out:
# area_type     0
# location      0
# total_sqft    0
# bath          0
# balcony       0
# price         0
# bhk           0
# dtype: int64

# %%
df['price_per_sqft']=(df['price']*100000)/df['total_sqft']

# %%
df
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 1                Plot  Area          Chikka Tirupathi      2600.0     5
# 2            Built-up  Area               Uttarahalli      1440.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# ...                     ...                       ...         ...   ...
# 13315        Built-up  Area                Whitefield      3453.0     4
# 13316  Super built-up  Area             Richards Town      3600.0     5
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0     2
# 13318  Super built-up  Area           Padmanabhanagar      4689.0     4
# 13319  Super built-up  Area              Doddathoguru       550.0     1
#
#        balcony   price  bhk  price_per_sqft
# 0            1   39.07    2     3699.810606
# ...

# %%
df['location']=df['location'].apply(lambda x: x.strip())

# %%
s=df['location'].value_counts()
p=s[s<=10]
df['location']=df['location'].apply(lambda x: 'other' if x in p else x)

# %%
df
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 1                Plot  Area          Chikka Tirupathi      2600.0     5
# 2            Built-up  Area               Uttarahalli      1440.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# ...                     ...                       ...         ...   ...
# 13315        Built-up  Area                Whitefield      3453.0     4
# 13316  Super built-up  Area                     other      3600.0     5
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0     2
# 13318  Super built-up  Area           Padmanabhanagar      4689.0     4
# 13319  Super built-up  Area              Doddathoguru       550.0     1
#
#        balcony   price  bhk  price_per_sqft
# 0            1   39.07    2     3699.810606
# ...

# %%
df=df[(df['total_sqft']/df['bhk'])>250]

# %%
df
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 1                Plot  Area          Chikka Tirupathi      2600.0     5
# 2            Built-up  Area               Uttarahalli      1440.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# ...                     ...                       ...         ...   ...
# 13315        Built-up  Area                Whitefield      3453.0     4
# 13316  Super built-up  Area                     other      3600.0     5
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0     2
# 13318  Super built-up  Area           Padmanabhanagar      4689.0     4
# 13319  Super built-up  Area              Doddathoguru       550.0     1
#
#        balcony   price  bhk  price_per_sqft
# 0            1   39.07    2     3699.810606
# ...

# %%
x=df[(df['total_sqft']/df['bhk']<300)]
x['bhk']=x['total_sqft']/500
x['bhk']=x['bhk'].round()
x['bath']=x['bhk']
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_16600\207943805.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['bhk']=x['total_sqft']/500
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_16600\207943805.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['bhk']=x['bhk'].round()
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_16600\207943805.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.update(x)
df.shape
# Out:
# (12667, 8)

# %%
xx=df
Q1 = xx['price_per_sqft'].quantile(0.25)
Q3 = xx['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
xx['price_per_sqft'] = xx['price_per_sqft'].apply(lambda x: min(max(x, lower_bound), upper_bound))
xx
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_16600\2129285229.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xx['price_per_sqft'] = xx['price_per_sqft'].apply(lambda x: min(max(x, lower_bound), upper_bound))
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 1                Plot  Area          Chikka Tirupathi      2600.0     5
# 2            Built-up  Area               Uttarahalli      1440.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# ...

# %%
df=xx
xx=df

# %%
xx['location']=xx['location'].str.strip()
# Out:
# C:\Users\suhanva savyasachi s\AppData\Local\Temp\ipykernel_16600\2699791774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xx['location']=xx['location'].str.strip()

# %%
df=xx
xx=df

# %%
xx
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 1                Plot  Area          Chikka Tirupathi      2600.0     5
# 2            Built-up  Area               Uttarahalli      1440.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# ...                     ...                       ...         ...   ...
# 13315        Built-up  Area                Whitefield      3453.0     4
# 13316  Super built-up  Area                     other      3600.0     5
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0     2
# 13318  Super built-up  Area           Padmanabhanagar      4689.0     4
# 13319  Super built-up  Area              Doddathoguru       550.0     1
#
#        balcony   price  bhk  price_per_sqft
# 0            1   39.07    2     3699.810606
# ...

# %%
xx['bhk'].value_counts()
# Out:
# bhk
# 2     5536
# 3     4784
# 4     1274
# 1      677
# 5      211
# 6       92
# 7       42
# 8       25
# 9       17
# 10       6
# 11       2
# 16       1
# Name: count, dtype: int64

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby(['location','area_type']):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
yy = remove_bhk_outliers(xx)
# df8 = df7.copy()
yy
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# 6      Super built-up  Area          Old Airport Road      2732.0     4
# 7      Super built-up  Area              Rajaji Nagar      3300.0     4
# ...                     ...                       ...         ...   ...
# 13314  Super built-up  Area         Green Glen Layout      1715.0     3
# 13316  Super built-up  Area                     other      3600.0     5
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0     2
# 13318  Super built-up  Area           Padmanabhanagar      4689.0     4
# 13319  Super built-up  Area              Doddathoguru       550.0     1
#
#        balcony   price  bhk  price_per_sqft
# 0            1   39.07    2     3699.810606
# ...

# %%
def plot_scatter_chart(df,location):
    bhk2 = df[(df.location==location) & (df.bhk==2)]
    bhk3 = df[(df.location==location) & (df.bhk==3)]
    plt.scatter(bhk2.total_sqft,bhk2.price,color='blue',label='2 BHK', s=50)
    plt.scatter(bhk3.total_sqft,bhk3.price,marker='+', color='green',label='3 BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()
    
plot_scatter_chart(yy,"Hebbal")

# %%
df=yy

# %%
df=df[~(df['bath']>=(df['bhk']+2))]

# %%
df=df[~(df['balcony']>=(df['bhk']+2))]

# %%
df
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# 6      Super built-up  Area          Old Airport Road      2732.0     4
# 7      Super built-up  Area              Rajaji Nagar      3300.0     4
# ...                     ...                       ...         ...   ...
# 13314  Super built-up  Area         Green Glen Layout      1715.0     3
# 13316  Super built-up  Area                     other      3600.0     5
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0     2
# 13318  Super built-up  Area           Padmanabhanagar      4689.0     4
# 13319  Super built-up  Area              Doddathoguru       550.0     1
#
#        balcony   price  bhk  price_per_sqft
# 0            1   39.07    2     3699.810606
# ...

# %%
df.drop(['price_per_sqft'],axis=1,inplace=True)
df
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# 6      Super built-up  Area          Old Airport Road      2732.0     4
# 7      Super built-up  Area              Rajaji Nagar      3300.0     4
# ...                     ...                       ...         ...   ...
# 13314  Super built-up  Area         Green Glen Layout      1715.0     3
# 13316  Super built-up  Area                     other      3600.0     5
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0     2
# 13318  Super built-up  Area           Padmanabhanagar      4689.0     4
# 13319  Super built-up  Area              Doddathoguru       550.0     1
#
#        balcony   price  bhk
# 0            1   39.07    2
# 3            1   95.00    3
# ...

# %%
xx['area_type'].value_counts()
# Out:
# area_type
# Super built-up  Area    6346
# Built-up  Area          1813
# Plot  Area              1200
# Carpet  Area              77
# Name: count, dtype: int64

# %%
xx.groupby('area_type')['price'].median()
# Out:
# area_type
# Built-up  Area           75.0
# Carpet  Area             65.4
# Plot  Area              165.0
# Super built-up  Area     72.0
# Name: price, dtype: float64

# %%
import pandas as pd
from scipy.stats import f_oneway

# Group data by category
groups = [group['price'] for _, group in xx.groupby('area_type')]

# Perform ANOVA test
f_statistic, p_value = f_oneway(*groups)

print("F-Statistic:", f_statistic)
print("P-Value:", p_value)
# Out:
# F-Statistic: 333.7502432869491
# P-Value: 5.561752372339251e-206

# %%
xx=df
dummies1 = pd.get_dummies(df.location)
dummies2 = pd.get_dummies(df.area_type)
dummies2
# Out:
#        Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area
# 0               False         False       False                  True
# 3               False         False       False                  True
# 4               False         False       False                  True
# 6               False         False       False                  True
# 7               False         False       False                  True
# ...               ...           ...         ...                   ...
# 13314           False         False       False                  True
# 13316           False         False       False                  True
# 13317            True         False       False                 False
# 13318           False         False       False                  True
# 13319           False         False       False                  True
#
# [9436 rows x 4 columns]

# %%
df=pd.concat([df,dummies1.drop('other',axis='columns'),dummies2.drop('Plot  Area',axis='columns')],axis='columns')
df
# Out:
#                   area_type                  location  total_sqft  bath  \
# 0      Super built-up  Area  Electronic City Phase II      1056.0     2
# 3      Super built-up  Area        Lingadheeranahalli      1521.0     3
# 4      Super built-up  Area                  Kothanur      1200.0     2
# 6      Super built-up  Area          Old Airport Road      2732.0     4
# 7      Super built-up  Area              Rajaji Nagar      3300.0     4
# ...                     ...                       ...         ...   ...
# 13314  Super built-up  Area         Green Glen Layout      1715.0     3
# 13316  Super built-up  Area                     other      3600.0     5
# 13317        Built-up  Area     Raja Rajeshwari Nagar      1141.0     2
# 13318  Super built-up  Area           Padmanabhanagar      4689.0     4
# 13319  Super built-up  Area              Doddathoguru       550.0     1
#
#        balcony   price  bhk  1st Block Jayanagar  1st Phase JP Nagar  \
# ...

# %%
df.drop(['area_type','location'],axis=1,inplace=True)
df
# Out:
#        total_sqft  bath  balcony   price  bhk  1st Block Jayanagar  \
# 0          1056.0     2        1   39.07    2                False
# 3          1521.0     3        1   95.00    3                False
# 4          1200.0     2        1   51.00    2                False
# 6          2732.0     4        2  204.00    4                False
# 7          3300.0     4        1  600.00    4                False
# ...           ...   ...      ...     ...  ...                  ...
# 13314      1715.0     3        3  112.00    3                False
# 13316      3600.0     5        1  400.00    4                False
# 13317      1141.0     2        1   60.00    2                False
# 13318      4689.0     4        1  488.00    4                False
# 13319       550.0     1        1   17.00    1                False
#
#        1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 0                   False                      False                 False
# ...

# %%
df.shape
# Out:
# (9436, 249)

# %%
x=df.drop('price',axis=1)
y=df['price']

# %%
x
# Out:
#        total_sqft  bath  balcony  bhk  1st Block Jayanagar  \
# 0          1056.0     2        1    2                False
# 3          1521.0     3        1    3                False
# 4          1200.0     2        1    2                False
# 6          2732.0     4        2    4                False
# 7          3300.0     4        1    4                False
# ...           ...   ...      ...  ...                  ...
# 13314      1715.0     3        3    3                False
# 13316      3600.0     5        1    4                False
# 13317      1141.0     2        1    2                False
# 13318      4689.0     4        1    4                False
# 13319       550.0     1        1    1                False
#
#        1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 0                   False                      False                 False
# 3                   False                      False                 False
# ...

# %%
y
# Out:
# 0         39.07
# 3         95.00
# 4         51.00
# 6        204.00
# 7        600.00
#           ...
# 13314    112.00
# 13316    400.00
# 13317     60.00
# 13318    488.00
# 13319     17.00
# Name: price, Length: 9436, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(xtrain,ytrain)
model.score(xtest,ytest)
# Out:
# 0.5867064821460222

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), x, y, cv=cv)
# Out:
# array([0.62444216, 0.56879615, 0.59473773, 0.57666658, 0.50923695])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'copy_X' : [True, False],
                'fit_intercept' : [True, False],
                'n_jobs' : [1,2,3],
                'positive' : [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 42
#      34         scores.append({
#      35             'model': algo_name,
#      36             'best_score': gs.best_score_,
#      37             'best_params': gs.best_params_
#      38         })
#      40     return pd.DataFrame(scores,columns=['model','best_score','best_params'])
# ---> 42 find_best_model_using_gridsearchcv(x,y)
#
# Cell In[104], line 33, in find_best_model_using_gridsearchcv(X, y)
#      31 for algo_name, config in algos.items():
#      32     gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
# ---> 33     gs.fit(X,y)
#      34     scores.append({
#      35         'model': algo_name,
#      36         'best_score': gs.best_score_,
#      37         'best_params': gs.best_params_
#      38     })
# ...
